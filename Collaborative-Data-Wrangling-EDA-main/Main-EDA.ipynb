# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.3.2-cp39-cp39-macosx_11_0_arm64.whl (10.8 MB)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Collecting numpy>=1.22.4
#   Using cached numpy-2.0.2-cp39-cp39-macosx_14_0_arm64.whl (5.3 MB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Requirement already satisfied: six>=1.5 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Installing collected packages: tzdata, pytz, numpy, pandas
# Successfully installed numpy-2.0.2 pandas-2.3.2 pytz-2025.2 tzdata-2025.2
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.9.4-cp39-cp39-macosx_11_0_arm64.whl (7.8 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.0-cp39-cp39-macosx_11_0_arm64.whl (249 kB)
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.59.2-cp39-cp39-macosx_10_9_universal2.whl (2.8 MB)
# Requirement already satisfied: packaging>=20.0 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from matplotlib) (25.0)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.7-cp39-cp39-macosx_11_0_arm64.whl (64 kB)
# Requirement already satisfied: numpy>=1.23 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from matplotlib) (2.0.2)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Collecting pillow>=8
#   Using cached pillow-11.3.0-cp39-cp39-macosx_11_0_arm64.whl (4.7 MB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: six>=1.5 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.0 cycler-0.12.1 fonttools-4.59.2 importlib-resources-6.5.2 kiwisolver-1.4.7 matplotlib-3.9.4 pillow-11.3.0 pyparsing-3.2.3
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from seaborn) (3.9.4)
# Requirement already satisfied: pandas>=1.2 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.5.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.23.0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# WARNING: You are using pip version 21.2.4; however, version 25.2 is available.
# You should consider upgrading via the '/Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/venv/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd  

df_tracks = pd.read_csv(
    r'/Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/Collaborative-Data-Wrangling-EDA-main/SpotifyFeatures.csv'
)

print(df_tracks.shape)
print(df_tracks.head())
# Out:
# (232725, 18)
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
# inspecting the dataset

df_tracks.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# 1       137373   0.737             0.000  F#    0.1510    -5.559  Minor
# 2       170267   0.131             0.000   C    0.1030   -13.879  Minor
# 3       152427   0.326             0.000  C#    0.0985   -12.178  Major
# 4        82625   0.225             0.123   F    0.2020   -21.150  Major
#
#    speechiness    tempo time_signature  valence
# 0       0.0525  166.969            4/4    0.814
# 1       0.0868  174.003            4/4    0.816
# 2       0.0362   99.488            5/4    0.368
# 3       0.0395  171.758            4/4    0.227
# 4       0.0456  140.576            4/4    0.390

# %%
df_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   genre             232725 non-null  object
#  1   artist_name       232725 non-null  object
#  2   track_name        232724 non-null  object
#  3   track_id          232725 non-null  object
#  4   popularity        232725 non-null  int64
#  5   acousticness      232725 non-null  float64
#  6   danceability      232725 non-null  float64
#  7   duration_ms       232725 non-null  int64
#  8   energy            232725 non-null  float64
#  9   instrumentalness  232725 non-null  float64
#  10  key               232725 non-null  object
#  11  liveness          232725 non-null  float64
#  12  loudness          232725 non-null  float64
#  13  mode              232725 non-null  object
#  14  speechiness       232725 non-null  float64
#  15  tempo             232725 non-null  float64
#  16  time_signature    232725 non-null  object
#  17  valence           232725 non-null  float64
# dtypes: float64(9), int64(2), object(7)
# memory usage: 32.0+ MB

# %%
df_tracks.isnull().sum()
# Out:
# genre               0
# artist_name         0
# track_name          1
# track_id            0
# popularity          0
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
df_tracks.describe().transpose()
# Out:
#                      count           mean            std          min  \
# popularity        232725.0      41.127502      18.189948      0.00000
# acousticness      232725.0       0.368560       0.354768      0.00000
# danceability      232725.0       0.554364       0.185608      0.05690
# duration_ms       232725.0  235122.339306  118935.909299  15387.00000
# energy            232725.0       0.570958       0.263456      0.00002
# instrumentalness  232725.0       0.148301       0.302768      0.00000
# liveness          232725.0       0.215009       0.198273      0.00967
# loudness          232725.0      -9.569885       5.998204    -52.45700
# speechiness       232725.0       0.120765       0.185518      0.02220
# tempo             232725.0     117.666585      30.898907     30.37900
# valence           232725.0       0.454917       0.260065      0.00000
#
#                           25%            50%          75%          max
# popularity            29.0000      43.000000      55.0000      100.000
# acousticness           0.0376       0.232000       0.7220        0.996
# danceability           0.4350       0.571000       0.6920        0.989
# duration_ms       182857.0000  220427.000000  265768.0000  5552917.000
# energy                 0.3850       0.605000       0.7870        0.999
# instrumentalness       0.0000       0.000044       0.0358        0.999
# liveness               0.0974       0.128000       0.2640        1.000
# loudness             -11.7710      -7.762000      -5.5010        3.744
# speechiness            0.0367       0.050100       0.1050        0.967
# tempo                 92.9590     115.778000     139.0540      242.903
# valence                0.2370       0.444000       0.6600        1.000

# %%
# Droping missing value seem safer since it’s just 1 out of many

df_tracks = df_tracks.dropna(subset=['track_name'])

# %%
# filter the popularity
sorted_df = df_tracks.sort_values('popularity', ascending = True).head(10)
sorted_df
# Out:
#                   genre             artist_name  \
# 0                 Movie          Henri Salvador
# 74954  Children's Music             Sing n Play
# 74958  Children's Music  Children Songs Company
# 74959  Children's Music  Children Songs Company
# 74961  Children's Music  Children Songs Company
# 74962  Children's Music  Children Songs Company
# 74963  Children's Music  Children Songs Company
# 74964  Children's Music             Sing n Play
# 56153             Movie         Bruno Pelletier
# 74966  Children's Music  Children Songs Company
#
#                                track_name                track_id  popularity  \
# 0             C'est beau de faire un Show  0BRjO6ga9RKCKjfDqeFgWV           0
# 74954                See, See My Playmate  3WaCwwpGoxLEkFmd6cpZO5           0
# 74958           By the God - Instrumental  5yDehr9ccZo3vBO8hZXFcK           0
# 74959  Interruption Please - Instrumental  6NEULw7AmTOAYRunPWcFvn           0
# 74961                              Breeze  6v126eNn1A79yFIKGfvqLz           0
# 74962                            Woodland  7qR2PWbDeuhh1Vzd0anb25           0
# 74963              Cool Me - Instrumental  0V3Q9RYUaiLKTJIvg4KCST           0
# 74964           The Tortoise and the Hare  0oX193rf5y87RipsZnH8Pq           0
# 56153                     Lié par le sang  3GO9Wo14FvMXvOKE4LItjg           0
# 74966                            Forsaken  1rRNU87xfqvxiUsEXXyi8k           0
#
#        acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 0            0.6110         0.389        99373  0.9100          0.000000  C#
# 74954        0.1390         0.556       150487  0.4390          0.006400   D
# 74958        0.2130         0.736       212547  0.4460          0.821000   D
# 74959        0.0131         0.639       184000  0.8440          0.095700  A#
# 74961        0.0280         0.607       147653  0.5540          0.000000   A
# 74962        0.9950         0.529       266067  0.1540          0.414000   B
# 74963        0.2500         0.623       350080  0.4710          0.931000  A#
# 74964        0.4960         0.563       201362  0.3460          0.000000   D
# 56153        0.0294         0.656       276027  0.6940          0.000017   A
# 74966        0.9940         0.429       129387  0.0382          0.000000   B
#
#        liveness  loudness   mode  speechiness    tempo time_signature  valence
# 0        0.3460    -1.828  Major       0.0525  166.969            4/4    0.814
# 74954    0.1720   -11.604  Major       0.0288  165.306            4/4    0.820
# 74958    0.2980   -12.328  Major       0.0504  130.011            4/4    0.668
# 74959    0.0399    -8.582  Minor       0.0439  120.027            4/4    0.271
# 74961    0.1690   -10.571  Major       0.3710   92.193            4/4    0.404
# 74962    0.1230    -9.222  Minor       0.0470   69.588            4/4    0.332
# 74963    0.2580    -8.675  Major       0.0332  120.015            4/4    0.515
# 74964    0.1200   -14.058  Major       0.0938  144.642            4/4    0.370
# 56153    0.0527    -6.755  Major       0.0273  120.085            4/4    0.449
# 74966    0.4480   -12.704  Major       0.0557  156.807            3/4    0.474

# %%
most_popular = df_tracks.query('popularity>90', inplace = False).sort_values('popularity', ascending = False )
most_popular[:10]
# Out:
#             genre    artist_name  \
# 107804        Pop  Ariana Grande
# 9027        Dance  Ariana Grande
# 9026        Dance  Ariana Grande
# 86951         Rap    Post Malone
# 107803        Pop    Post Malone
# 107802        Pop  Ariana Grande
# 138918  Reggaeton   Daddy Yankee
# 66643     Hip-Hop   Daddy Yankee
# 107909        Pop   Daddy Yankee
# 86953         Rap    Post Malone
#
#                                            track_name                track_id  \
# 107804                                        7 rings  14msK75pk3pA33pzPVNtBF
# 9027                                          7 rings  14msK75pk3pA33pzPVNtBF
# 9026         break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# 86951                                            Wow.  6MWtB6iiXyIwun0YzU6DFP
# 107803                                           Wow.  6MWtB6iiXyIwun0YzU6DFP
# 107802       break up with your girlfriend, i'm bored  4kV4N9D1iKVxx1KLvtTpjS
# 138918                                      Con Calma  5w9c2J52mkdntKOmRLeM2m
# 66643                                       Con Calma  5w9c2J52mkdntKOmRLeM2m
# 107909                                      Con Calma  5w9c2J52mkdntKOmRLeM2m
# 86953   Sunflower - Spider-Man: Into the Spider-Verse  3KkXRkHbMCARz0aVfEt68P
#
#         popularity  acousticness  danceability  duration_ms  energy  \
# 107804         100        0.5780         0.725       178640   0.321
# 9027           100        0.5780         0.725       178640   0.321
# 9026            99        0.0421         0.726       190440   0.554
# 86951           99        0.1630         0.833       149520   0.539
# 107803          99        0.1630         0.833       149520   0.539
# 107802          99        0.0421         0.726       190440   0.554
# 138918          98        0.1100         0.737       193227   0.860
# 66643           98        0.1100         0.737       193227   0.860
# 107909          98        0.1100         0.737       193227   0.860
# 86953           97        0.5560         0.760       158040   0.479
#
#         instrumentalness key  liveness  loudness   mode  speechiness    tempo  \
# 107804          0.000000  C#    0.0884   -10.744  Minor       0.3230   70.142
# 9027            0.000000  C#    0.0884   -10.744  Minor       0.3230   70.142
# 9026            0.000000   F    0.1060    -5.290  Minor       0.0917  169.999
# 86951           0.000002   B    0.1010    -7.399  Minor       0.1780   99.947
# 107803          0.000002   B    0.1010    -7.399  Minor       0.1780   99.947
# 107802          0.000000   F    0.1060    -5.290  Minor       0.0917  169.999
# 138918          0.000002  G#    0.0574    -2.652  Minor       0.0593   93.989
# 66643           0.000002  G#    0.0574    -2.652  Minor       0.0593   93.989
# 107909          0.000002  G#    0.0574    -2.652  Minor       0.0593   93.989
# 86953           0.000000   D    0.0703    -5.574  Major       0.0466   89.911
#
#        time_signature  valence
# 107804            4/4    0.319
# 9027              4/4    0.319
# 9026              4/4    0.335
# 86951             4/4    0.385
# 107803            4/4    0.385
# 107802            4/4    0.335
# 138918            4/4    0.656
# 66643             4/4    0.656
# 107909            4/4    0.656
# 86953             4/4    0.913

# %%
df_tracks["duration"]= df_tracks["duration_ms"].apply(lambda x: round(x/1000))
df_tracks.drop("duration_ms", inplace=True, axis=1)

# %%
df_tracks.duration.head()
# Out:
# 0     99
# 1    137
# 2    170
# 3    152
# 4     83
# Name: duration, dtype: int64

# %%
# keep only numeric columns, then optionally drop some
num_cols = df_tracks.select_dtypes(include='number').columns.difference(['key', 'mode'])
corr_df = df_tracks[num_cols].corr(method='pearson')

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 6))
ax = sns.heatmap(
    corr_df, annot=True, fmt=".1g",
    vmin=-1, vmax=1, center=0, cmap="inferno",
    linewidths=1, linecolor="black"
)
ax.set_title("Correlation Heatmap Between Numeric Variables")
ax.set_xticklabels(ax.get_xticklabels(), rotation=90)
plt.tight_layout()

# %% [markdown]
# Further Steps of Data Cleaning (Performed by: Eva Kaushik)
# 1. Standardised Column names (lower case + replacing space with underscore)
# 2. Handling duplicates [Spotify dataset repeat rows (same track_id)]
# 3. Refine Duration (Instead of seconds, converted to minutes (float, 2 decimals) for easier interpretation)
# 4. Categorical Consistency: Some columns (key, mode, time_signature) might have unexpected values — check their unique values.
# 5. Saved Cleaned Dataset

# %%
#Standardize the column names 
df_tracks.columns = [c.strip().lower().replace(" ", "_") for c in df_tracks.columns]

# %%
# Handles Duplicate
df_tracks = df_tracks.drop_duplicates(subset="track_id")

# %%
# Refine duration 
df_tracks["duration_min"] = df_tracks["duration"] / 60

# %%
#Checking Categorical Consistency 
print(df_tracks["key"].unique())
print(df_tracks["mode"].unique())
print(df_tracks["time_signature"].unique())
# Out:
# ['C#' 'F#' 'C' 'F' 'G' 'E' 'D#' 'G#' 'D' 'A#' 'A' 'B']
# ['Major' 'Minor']
# ['4/4' '5/4' '3/4' '1/4' '0/4']

# %%
import os

data_folder = "/Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/Collaborative-Data-Wrangling-EDA-main/data"
os.makedirs(data_folder, exist_ok=True)

df_tracks.to_csv(os.path.join(data_folder, "spotify_cleaned.csv"), index=False)

# %% [markdown]
# Exploratory Data Analysis (Performed by: Eva Kaushik)
# 1. Loading the cleaned data (checked column names)
# 2. Computing Mean, Median and Correlation
# 3. Histogram of Track Duration (Frequency vs. Duration)
# 4. Scatter Plot (Danceability vs. Energy)
# 5. Correlation Heatmap

# %%
import pandas as pd

df = pd.read_csv("/Users/ekaushik/Desktop/Collaborative-Data-Wrangling-EDA/Collaborative-Data-Wrangling-EDA-main/data/spotify_cleaned.csv")
df.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  energy  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389   0.910
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590   0.737
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663   0.131
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240   0.326
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331   0.225
#
#    instrumentalness key  liveness  loudness   mode  speechiness    tempo  \
# 0             0.000  C#    0.3460    -1.828  Major       0.0525  166.969
# 1             0.000  F#    0.1510    -5.559  Minor       0.0868  174.003
# 2             0.000   C    0.1030   -13.879  Minor       0.0362   99.488
# 3             0.000  C#    0.0985   -12.178  Major       0.0395  171.758
# 4             0.123   F    0.2020   -21.150  Major       0.0456  140.576
#
#   time_signature  valence  duration  duration_min
# 0            4/4    0.814        99      1.650000
# 1            4/4    0.816       137      2.283333
# 2            5/4    0.368       170      2.833333
# 3            4/4    0.227       152      2.533333
# 4            4/4    0.390        83      1.383333

# %%
print(df.columns.tolist())
# Out:
# ['genre', 'artist_name', 'track_name', 'track_id', 'popularity', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence', 'duration', 'duration_min']

# %%
# Computing mean, median, and correlation
mean_duration = df['duration_min'].mean()
median_duration = df['duration_min'].median()
correlation = df[['danceability', 'energy']].corr().iloc[0,1]

print(f"Mean Duration (min): {mean_duration:.2f}")
print(f"Median Duration (min): {median_duration:.2f}")
print(f"Correlation (Danceability vs Energy): {correlation:.2f}")
# Out:
# Mean Duration (min): 3.94
# Median Duration (min): 3.65
# Correlation (Danceability vs Energy): 0.37

# %%
#Histogram of Track Duration 
plt.figure(figsize=(10,6))
sns.histplot(df['duration_min'], bins=30, kde=True)
plt.title("Distribution of Track Duration (minutes)")
plt.xlabel("Duration (minutes)")
plt.ylabel("Frequency")
plt.show()

# %%
#Scatterplot 
plt.figure(figsize=(10,6))
sns.scatterplot(x='danceability', y='energy', data=df)
plt.title("Danceability vs Energy")
plt.xlabel("Danceability")
plt.ylabel("Energy")
plt.show()

# %%
# Correlation Heatmap
numeric_df = df.select_dtypes(include='number')
plt.figure(figsize=(12,8))
sns.heatmap(numeric_df.corr(), annot=True, fmt=".2f", cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
